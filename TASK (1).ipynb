# %% [markdown]
# # Q1. Find the total units produced by each product_category.

# %%
import pandas as pd
df=pd.read_csv('production_analysis_dataset.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   production_id           50 non-null     int64
#  1   product_category        50 non-null     object
#  2   factory                 50 non-null     object
#  3   shift                   50 non-null     object
#  4   supervisor              50 non-null     object
#  5   units_produced          50 non-null     int64
#  6   defective_units         50 non-null     int64
#  7   production_time_hr      50 non-null     float64
#  8   machine_downtime_hr     50 non-null     float64
#  9   energy_consumption_kwh  50 non-null     int64
#  10  profit                  50 non-null     int64
# dtypes: float64(2), int64(5), object(4)
# memory usage: 4.4+ KB

# %% [markdown]
# # Q2. Calculate the average profit for each factory.

# %%
df.groupby('product_category')['units_produced'].sum()
df.groupby('factory')['profit'].mean()
# Out:
# factory
# Plant_A    18044.375000
# Plant_B    16973.384615
# Plant_C    18086.076923
# Name: profit, dtype: float64

# %% [markdown]
# # Q3. Find the total defective_units for each shift.

# %%
df.groupby('shift')['defective_units'].sum()
# Out:
# shift
# Evening    132
# Morning    472
# Night      471
# Name: defective_units, dtype: int64

# %% [markdown]
# # Q4. Calculate the average production_time_hr for each supervisor.

# %%
df.groupby('shift')['supervisor'].sum()
# Out:
# shift
# Evening                                  S3S3S1S1S4S3S1
# Morning    S3S2S3S3S4S1S3S2S1S1S1S4S2S4S3S3S3S1S2S2S4S3
# Night        S1S2S4S3S4S2S1S4S2S4S4S4S3S1S3S2S4S2S3S4S2
# Name: supervisor, dtype: object

# %% [markdown]
# # Q5. Find the total energy_consumption_kwh for each factory and shift.

# %% [markdown]
# # Q6. For each product_category, calculate:
# total units_produced
# average profit
# maximum defective_units.

# %% [markdown]
# # Q7. For each factory, calculate:
# mean production_time_hr
# median machine_downtime_hr.

# %% [markdown]
# # Q8. For each shift, compute:
# minimum profit
# maximum profit
# average units_produced.

# %% [markdown]
# # Q9. For each supervisor, calculate:
# total units_produced
# total defective_units.

# %% [markdown]
# # Q10. Using apply(), calculate the defect rate for each row:
# defect_rate=defective_units/units_produced

# %%
df['defect_rate']=df.apply(lambda x: x['defective_units']/x ['units_produced'],axis=1)
df
# Out:
#     production_id product_category  factory    shift supervisor  \
# 0             101       Automotive  Plant_A    Night         S1
# 1             102       Automotive  Plant_A    Night         S2
# 2             103      Electronics  Plant_A    Night         S4
# 3             104      Electronics  Plant_B  Morning         S3
# 4             105        Furniture  Plant_A    Night         S3
# 5             106      Electronics  Plant_B  Morning         S2
# 6             107        Furniture  Plant_B  Morning         S3
# 7             108      Electronics  Plant_B  Evening         S3
# 8             109      Electronics  Plant_A  Morning         S3
# 9             110       Automotive  Plant_B  Morning         S4
# 10            111       Automotive  Plant_B    Night         S4
# 11            112        Furniture  Plant_A  Morning         S1
# 12            113        Furniture  Plant_C  Evening         S3
# 13            114        Furniture  Plant_C  Evening         S1
# 14            115       Automotive  Plant_B    Night         S2
# 15            116       Automotive  Plant_A  Morning         S3
# 16            117       Automotive  Plant_B  Evening         S1
# 17            118      Electronics  Plant_A    Night         S1
# 18            119      Electronics  Plant_A    Night         S4
# 19            120       Automotive  Plant_C    Night         S2
# 20            121       Automotive  Plant_B  Morning         S2
# 21            122      Electronics  Plant_A  Morning         S1
# 22            123      Electronics  Plant_B    Night         S4
# 23            124        Furniture  Plant_A  Evening         S4
# 24            125        Furniture  Plant_C  Morning         S1
# 25            126      Electronics  Plant_A    Night         S4
# 26            127       Automotive  Plant_A  Morning         S1
# 27            128        Furniture  Plant_A  Morning         S4
# 28            129        Furniture  Plant_C    Night         S4
# 29            130       Automotive  Plant_A    Night         S3
# 30            131      Electronics  Plant_C  Morning         S2
# 31            132       Automotive  Plant_A    Night         S1
# 32            133        Furniture  Plant_A    Night         S3
# 33            134        Furniture  Plant_A  Morning         S4
# 34            135        Furniture  Plant_A  Morning         S3
# 35            136       Automotive  Plant_C  Morning         S3
# 36            137      Electronics  Plant_C    Night         S2
# 37            138       Automotive  Plant_B    Night         S4
# 38            139      Electronics  Plant_B  Morning         S3
# 39            140      Electronics  Plant_C  Morning         S1
# 40            141      Electronics  Plant_B  Morning         S2
# 41            142       Automotive  Plant_A  Morning         S2
# 42            143        Furniture  Plant_C    Night         S2
# 43            144        Furniture  Plant_A  Morning         S4
# 44            145       Automotive  Plant_A  Evening         S3
# 45            146        Furniture  Plant_C    Night         S3
# 46            147      Electronics  Plant_A    Night         S4
# 47            148       Automotive  Plant_A  Evening         S1
# 48            149       Automotive  Plant_C    Night         S2
# 49            150        Furniture  Plant_C  Morning         S3
#
#     units_produced  defective_units  production_time_hr  machine_downtime_hr  \
# 0              627               12                6.58                 0.56
# 1              602               32                6.60                 0.32
# 2              666               39                7.76                 0.78
# 3              474               22                6.97                 1.44
# 4              476               21                8.92                 1.15
# 5              621               28                8.23                 1.12
# 6              351               29                7.33                 1.03
# 7              659                9                8.33                 0.42
# 8              627               40                7.16                 0.62
# 9              505               22                6.70                 1.39
# 10             502               34                6.93                 0.38
# 11             598               30                7.59                 1.50
# 12             378               15                8.88                 0.75
# 13             583                5                8.54                 0.35
# 14             450               32                6.97                 0.20
# 15             559               11                9.11                 0.59
# 16             690               15                8.12                 1.21
# 17             357               28                9.14                 1.28
# 18             343               36                8.95                 1.47
# 19             581               15                7.30                 1.33
# 20             665               24                7.70                 1.07
# 21             415                9                7.51                 0.96
# 22             417                9                9.22                 1.32
# 23             409               39                6.90                 1.42
# 24             397               11                6.79                 0.76
# 25             331               30                8.68                 1.24
# 26             371               32                7.05                 0.80
# 27             347               20                7.00                 0.83
# 28             301               29                7.30                 1.22
# 29             379               17                7.39                 1.46
# 30             329                8                8.25                 0.85
# 31             335                9                8.53                 0.51
# 32             617               10                7.76                 0.96
# 33             422               21                7.69                 1.07
# 34             618               11                6.72                 0.48
# 35             445               15                7.81                 0.91
# 36             639               11                9.32                 0.37
# 37             439               23                8.31                 1.13
# 38             428                8                6.78                 0.75
# 39             382               33                8.16                 0.76
# 40             489               40                6.94                 0.37
# 41             641               11                7.56                 0.93
# 42             390               31                6.57                 1.16
# 43             436               15                8.86                 0.34
# 44             479               24                8.96                 1.33
# 45             442                9                9.40                 0.56
# 46             314               12                9.13                 0.54
# 47             476               25                7.81                 1.48
# 48             662               32                6.51                 1.40
# 49             486               32                6.71                 1.06
#
#     energy_consumption_kwh  profit  defect_rate
# 0                     1028   12286     0.019139
# 1                     1038   18279     0.053156
# 2                     1084   23261     0.058559
# 3                     1144   11674     0.046414
# 4                     1349   12045     0.044118
# 5                      846   20834     0.045089
# 6                     1173   12664     0.082621
# 7                     1546   14010     0.013657
# 8                     1586   22713     0.063796
# 9                     1380   24358     0.043564
# 10                    1562   19197     0.067729
# 11                     941   18348     0.050167
# 12                     865   16304     0.039683
# 13                    1349   22302     0.008576
# 14                    1539   24349     0.071111
# 15                    1454   18317     0.019678
# 16                    1343   10009     0.021739
# 17                    1114   13923     0.078431
# 18                    1345   22547     0.104956
# 19                    1233   13470     0.025818
# 20                    1182   17177     0.036090
# 21                    1035   19641     0.021687
# 22                     872   18423     0.021583
# 23                    1384   19440     0.095355
# 24                    1233   16735     0.027708
# 25                     911   14073     0.090634
# 26                     877   17260     0.086253
# 27                    1018   24166     0.057637
# 28                    1265   14673     0.096346
# 29                    1393   22054     0.044855
# 30                    1343   12579     0.024316
# 31                     922   24586     0.026866
# 32                    1335   15183     0.016207
# 33                    1107   17491     0.049763
# 34                    1071   12170     0.017799
# 35                    1109   20021     0.033708
# 36                     918   24577     0.017214
# 37                    1008   21263     0.052392
# 38                    1083   10722     0.018692
# 39                     809   11832     0.086387
# 40                    1115   15974     0.081800
# 41                    1216   20168     0.017161
# 42                    1140   22818     0.079487
# 43                     839   24067     0.034404
# 44                    1028   10387     0.050104
# 45                    1456   18346     0.020362
# 46                    1394   14349     0.038217
# 47                     918   16311     0.052521
# 48                    1351   21253     0.048338
# 49                    1138   20209     0.065844

# %% [markdown]
# # Q11. Using groupby().apply(), find the profit range (max − min) for each factory.

# %%
df.groupby ('factory').apply(lambda x: x['profit'].max()-x['profit'].min())
# Out:
# C:\Users\LJENG\AppData\Local\Temp\ipykernel_1520\933945742.py:1: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df.groupby ('factory').apply(lambda x: x['profit'].max()-x['profit'].min())
# factory
# Plant_A    14199
# Plant_B    14349
# Plant_C    12745
# dtype: int64

# %% [markdown]
# # Q12. Using groupby().apply(), find the row with maximum units_produced in each product_category.

# %%
count=0

for i in df.groupby ('product_category'):
    count=+1
    print(i)
df.groupby('product_category').apply(lambda x :x.sort_values(by='units_producer',ascending=False).head(1))
# Out:
# ('Automotive',     production_id product_category  factory    shift supervisor  \
# 0             101       Automotive  Plant_A    Night         S1
# 1             102       Automotive  Plant_A    Night         S2
# 9             110       Automotive  Plant_B  Morning         S4
# 10            111       Automotive  Plant_B    Night         S4
# 14            115       Automotive  Plant_B    Night         S2
# 15            116       Automotive  Plant_A  Morning         S3
# 16            117       Automotive  Plant_B  Evening         S1
# 19            120       Automotive  Plant_C    Night         S2
# 20            121       Automotive  Plant_B  Morning         S2
# 26            127       Automotive  Plant_A  Morning         S1
# 29            130       Automotive  Plant_A    Night         S3
# 31            132       Automotive  Plant_A    Night         S1
# 35            136       Automotive  Plant_C  Morning         S3
# 37            138       Automotive  Plant_B    Night         S4
# 41            142       Automotive  Plant_A  Morning         S2
# 44            145       Automotive  Plant_A  Evening         S3
# 47            148       Automotive  Plant_A  Evening         S1
# 48            149       Automotive  Plant_C    Night         S2
#
#     units_produced  defective_units  production_time_hr  machine_downtime_hr  \
# 0              627               12                6.58                 0.56
# 1              602               32                6.60                 0.32
# 9              505               22                6.70                 1.39
# 10             502               34                6.93                 0.38
# 14             450               32                6.97                 0.20
# 15             559               11                9.11                 0.59
# 16             690               15                8.12                 1.21
# 19             581               15                7.30                 1.33
# 20             665               24                7.70                 1.07
# 26             371               32                7.05                 0.80
# 29             379               17                7.39                 1.46
# 31             335                9                8.53                 0.51
# 35             445               15                7.81                 0.91
# 37             439               23                8.31                 1.13
# 41             641               11                7.56                 0.93
# 44             479               24                8.96                 1.33
# 47             476               25                7.81                 1.48
# 48             662               32                6.51                 1.40
#
#     energy_consumption_kwh  profit  defect_rate
# 0                     1028   12286     0.019139
# 1                     1038   18279     0.053156
# 9                     1380   24358     0.043564
# 10                    1562   19197     0.067729
# 14                    1539   24349     0.071111
# 15                    1454   18317     0.019678
# 16                    1343   10009     0.021739
# 19                    1233   13470     0.025818
# 20                    1182   17177     0.036090
# 26                     877   17260     0.086253
# 29                    1393   22054     0.044855
# 31                     922   24586     0.026866
# 35                    1109   20021     0.033708
# 37                    1008   21263     0.052392
# 41                    1216   20168     0.017161
# 44                    1028   10387     0.050104
# 47                     918   16311     0.052521
# 48                    1351   21253     0.048338  )
# ('Electronics',     production_id product_category  factory    shift supervisor  \
# 2             103      Electronics  Plant_A    Night         S4
# 3             104      Electronics  Plant_B  Morning         S3
# 5             106      Electronics  Plant_B  Morning         S2
# 7             108      Electronics  Plant_B  Evening         S3
# 8             109      Electronics  Plant_A  Morning         S3
# 17            118      Electronics  Plant_A    Night         S1
# 18            119      Electronics  Plant_A    Night         S4
# 21            122      Electronics  Plant_A  Morning         S1
# 22            123      Electronics  Plant_B    Night         S4
# 25            126      Electronics  Plant_A    Night         S4
# 30            131      Electronics  Plant_C  Morning         S2
# 36            137      Electronics  Plant_C    Night         S2
# 38            139      Electronics  Plant_B  Morning         S3
# 39            140      Electronics  Plant_C  Morning         S1
# 40            141      Electronics  Plant_B  Morning         S2
# 46            147      Electronics  Plant_A    Night         S4
#
#     units_produced  defective_units  production_time_hr  machine_downtime_hr  \
# 2              666               39                7.76                 0.78
# 3              474               22                6.97                 1.44
# 5              621               28                8.23                 1.12
# 7              659                9                8.33                 0.42
# 8              627               40                7.16                 0.62
# 17             357               28                9.14                 1.28
# 18             343               36                8.95                 1.47
# 21             415                9                7.51                 0.96
# 22             417                9                9.22                 1.32
# 25             331               30                8.68                 1.24
# 30             329                8                8.25                 0.85
# 36             639               11                9.32                 0.37
# 38             428                8                6.78                 0.75
# 39             382               33                8.16                 0.76
# 40             489               40                6.94                 0.37
# 46             314               12                9.13                 0.54
#
#     energy_consumption_kwh  profit  defect_rate
# 2                     1084   23261     0.058559
# 3                     1144   11674     0.046414
# 5                      846   20834     0.045089
# 7                     1546   14010     0.013657
# 8                     1586   22713     0.063796
# 17                    1114   13923     0.078431
# 18                    1345   22547     0.104956
# 21                    1035   19641     0.021687
# 22                     872   18423     0.021583
# 25                     911   14073     0.090634
# 30                    1343   12579     0.024316
# 36                     918   24577     0.017214
# 38                    1083   10722     0.018692
# 39                     809   11832     0.086387
# 40                    1115   15974     0.081800
# 46                    1394   14349     0.038217  )
# ('Furniture',     production_id product_category  factory    shift supervisor  \
# 4             105        Furniture  Plant_A    Night         S3
# 6             107        Furniture  Plant_B  Morning         S3
# 11            112        Furniture  Plant_A  Morning         S1
# 12            113        Furniture  Plant_C  Evening         S3
# 13            114        Furniture  Plant_C  Evening         S1
# 23            124        Furniture  Plant_A  Evening         S4
# 24            125        Furniture  Plant_C  Morning         S1
# 27            128        Furniture  Plant_A  Morning         S4
# 28            129        Furniture  Plant_C    Night         S4
# 32            133        Furniture  Plant_A    Night         S3
# 33            134        Furniture  Plant_A  Morning         S4
# 34            135        Furniture  Plant_A  Morning         S3
# 42            143        Furniture  Plant_C    Night         S2
# 43            144        Furniture  Plant_A  Morning         S4
# 45            146        Furniture  Plant_C    Night         S3
# 49            150        Furniture  Plant_C  Morning         S3
#
#     units_produced  defective_units  production_time_hr  machine_downtime_hr  \
# 4              476               21                8.92                 1.15
# 6              351               29                7.33                 1.03
# 11             598               30                7.59                 1.50
# 12             378               15                8.88                 0.75
# 13             583                5                8.54                 0.35
# 23             409               39                6.90                 1.42
# 24             397               11                6.79                 0.76
# 27             347               20                7.00                 0.83
# 28             301               29                7.30                 1.22
# 32             617               10                7.76                 0.96
# 33             422               21                7.69                 1.07
# 34             618               11                6.72                 0.48
# 42             390               31                6.57                 1.16
# 43             436               15                8.86                 0.34
# 45             442                9                9.40                 0.56
# 49             486               32                6.71                 1.06
#
#     energy_consumption_kwh  profit  defect_rate
# 4                     1349   12045     0.044118
# 6                     1173   12664     0.082621
# 11                     941   18348     0.050167
# 12                     865   16304     0.039683
# 13                    1349   22302     0.008576
# 23                    1384   19440     0.095355
# 24                    1233   16735     0.027708
# 27                    1018   24166     0.057637
# 28                    1265   14673     0.096346
# 32                    1335   15183     0.016207
# 33                    1107   17491     0.049763
# 34                    1071   12170     0.017799
# 42                    1140   22818     0.079487
# 43                     839   24067     0.034404
# 45                    1456   18346     0.020362
# 49                    1138   20209     0.065844  )
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1520\2031617179.py in ?()
#       2
#       3 for i in df.groupby ('product_category'):
#       4     count=+1
#       5     print(i)
# ----> 6 df.groupby('product_category').apply(lambda x :x.sort_values(by='units_producer',ascending=False).head(1))
#
# C:\ProgramData\Anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py in ?(self, func, include_groups, *args, **kwargs)
#    1835                         ),
#    1836                         category=FutureWarning,
#    1837                         stacklevel=find_stack_level(),
#    1838                     )
# -> 1839             except TypeError:
#    1840                 # gh-20949
#    1841                 # try again, with .apply acting as a filtering
#    1842                 # operation, by excluding the grouping column
#
# C:\ProgramData\Anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py in ?(self, f, data, not_indexed_same, is_transform, is_agg)
#    1883         -------
#    1884         Series or DataFrame
#    1885             data after applying f
#    1886         """
# -> 1887         values, mutated = self._grouper.apply_groupwise(f, data, self.axis)
#    1888         if not_indexed_same is None:
#    1889             not_indexed_same = mutated
#    1890
#
# C:\ProgramData\Anaconda3\Lib\site-packages\pandas\core\groupby\ops.py in ?(self, f, data, axis)
#     924             object.__setattr__(group, "name", key)
#     925
#     926             # group might be modified
#     927             group_axes = group.axes
# --> 928             res = f(group)
#     929             if not mutated and not _is_indexed_like(res, group_axes, axis):
#     930                 mutated = True
#     931             result_values.append(res)
#
# ~\AppData\Local\Temp\ipykernel_1520\2031617179.py in ?(x)
# ----> 6 df.groupby('product_category').apply(lambda x :x.sort_values(by='units_producer',ascending=False).head(1))
#
# C:\ProgramData\Anaconda3\Lib\site-packages\pandas\core\frame.py in ?(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    7207             )
#    7208         elif len(by):
#    7209             # len(by) == 1
#    7210
# -> 7211             k = self._get_label_or_level_values(by[0], axis=axis)
#    7212
#    7213             # need to rewrap column in Series to apply key function
#    7214             if key is not None:
#
# C:\ProgramData\Anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, key, axis)
#    1910             values = self.xs(key, axis=other_axes[0])._values
#    1911         elif self._is_level_reference(key, axis=axis):
#    1912             values = self.axes[axis].get_level_values(key)._values
#    1913         else:
# -> 1914             raise KeyError(key)
#    1915
#    1916         # Check for duplicates
#    1917         if values.ndim > 1:
#
# KeyError: 'units_producer'

# %% [markdown]
# # Q13. Use apply() to create a new column efficiency_score:
# efficiency=units_produced/production_time_hr

# %%
df['efficiency_score']=df.apply(lambda x: x['units_produced']/x['production_time_hr'],axis=1)
df
# Out:
#     production_id product_category  factory    shift supervisor  \
# 0             101       Automotive  Plant_A    Night         S1
# 1             102       Automotive  Plant_A    Night         S2
# 2             103      Electronics  Plant_A    Night         S4
# 3             104      Electronics  Plant_B  Morning         S3
# 4             105        Furniture  Plant_A    Night         S3
# 5             106      Electronics  Plant_B  Morning         S2
# 6             107        Furniture  Plant_B  Morning         S3
# 7             108      Electronics  Plant_B  Evening         S3
# 8             109      Electronics  Plant_A  Morning         S3
# 9             110       Automotive  Plant_B  Morning         S4
# 10            111       Automotive  Plant_B    Night         S4
# 11            112        Furniture  Plant_A  Morning         S1
# 12            113        Furniture  Plant_C  Evening         S3
# 13            114        Furniture  Plant_C  Evening         S1
# 14            115       Automotive  Plant_B    Night         S2
# 15            116       Automotive  Plant_A  Morning         S3
# 16            117       Automotive  Plant_B  Evening         S1
# 17            118      Electronics  Plant_A    Night         S1
# 18            119      Electronics  Plant_A    Night         S4
# 19            120       Automotive  Plant_C    Night         S2
# 20            121       Automotive  Plant_B  Morning         S2
# 21            122      Electronics  Plant_A  Morning         S1
# 22            123      Electronics  Plant_B    Night         S4
# 23            124        Furniture  Plant_A  Evening         S4
# 24            125        Furniture  Plant_C  Morning         S1
# 25            126      Electronics  Plant_A    Night         S4
# 26            127       Automotive  Plant_A  Morning         S1
# 27            128        Furniture  Plant_A  Morning         S4
# 28            129        Furniture  Plant_C    Night         S4
# 29            130       Automotive  Plant_A    Night         S3
# 30            131      Electronics  Plant_C  Morning         S2
# 31            132       Automotive  Plant_A    Night         S1
# 32            133        Furniture  Plant_A    Night         S3
# 33            134        Furniture  Plant_A  Morning         S4
# 34            135        Furniture  Plant_A  Morning         S3
# 35            136       Automotive  Plant_C  Morning         S3
# 36            137      Electronics  Plant_C    Night         S2
# 37            138       Automotive  Plant_B    Night         S4
# 38            139      Electronics  Plant_B  Morning         S3
# 39            140      Electronics  Plant_C  Morning         S1
# 40            141      Electronics  Plant_B  Morning         S2
# 41            142       Automotive  Plant_A  Morning         S2
# 42            143        Furniture  Plant_C    Night         S2
# 43            144        Furniture  Plant_A  Morning         S4
# 44            145       Automotive  Plant_A  Evening         S3
# 45            146        Furniture  Plant_C    Night         S3
# 46            147      Electronics  Plant_A    Night         S4
# 47            148       Automotive  Plant_A  Evening         S1
# 48            149       Automotive  Plant_C    Night         S2
# 49            150        Furniture  Plant_C  Morning         S3
#
#     units_produced  defective_units  production_time_hr  machine_downtime_hr  \
# 0              627               12                6.58                 0.56
# 1              602               32                6.60                 0.32
# 2              666               39                7.76                 0.78
# 3              474               22                6.97                 1.44
# 4              476               21                8.92                 1.15
# 5              621               28                8.23                 1.12
# 6              351               29                7.33                 1.03
# 7              659                9                8.33                 0.42
# 8              627               40                7.16                 0.62
# 9              505               22                6.70                 1.39
# 10             502               34                6.93                 0.38
# 11             598               30                7.59                 1.50
# 12             378               15                8.88                 0.75
# 13             583                5                8.54                 0.35
# 14             450               32                6.97                 0.20
# 15             559               11                9.11                 0.59
# 16             690               15                8.12                 1.21
# 17             357               28                9.14                 1.28
# 18             343               36                8.95                 1.47
# 19             581               15                7.30                 1.33
# 20             665               24                7.70                 1.07
# 21             415                9                7.51                 0.96
# 22             417                9                9.22                 1.32
# 23             409               39                6.90                 1.42
# 24             397               11                6.79                 0.76
# 25             331               30                8.68                 1.24
# 26             371               32                7.05                 0.80
# 27             347               20                7.00                 0.83
# 28             301               29                7.30                 1.22
# 29             379               17                7.39                 1.46
# 30             329                8                8.25                 0.85
# 31             335                9                8.53                 0.51
# 32             617               10                7.76                 0.96
# 33             422               21                7.69                 1.07
# 34             618               11                6.72                 0.48
# 35             445               15                7.81                 0.91
# 36             639               11                9.32                 0.37
# 37             439               23                8.31                 1.13
# 38             428                8                6.78                 0.75
# 39             382               33                8.16                 0.76
# 40             489               40                6.94                 0.37
# 41             641               11                7.56                 0.93
# 42             390               31                6.57                 1.16
# 43             436               15                8.86                 0.34
# 44             479               24                8.96                 1.33
# 45             442                9                9.40                 0.56
# 46             314               12                9.13                 0.54
# 47             476               25                7.81                 1.48
# 48             662               32                6.51                 1.40
# 49             486               32                6.71                 1.06
#
#     energy_consumption_kwh  profit  defect_rate  efficiency_score
# 0                     1028   12286     0.019139         95.288754
# 1                     1038   18279     0.053156         91.212121
# 2                     1084   23261     0.058559         85.824742
# 3                     1144   11674     0.046414         68.005739
# 4                     1349   12045     0.044118         53.363229
# 5                      846   20834     0.045089         75.455650
# 6                     1173   12664     0.082621         47.885402
# 7                     1546   14010     0.013657         79.111645
# 8                     1586   22713     0.063796         87.569832
# 9                     1380   24358     0.043564         75.373134
# 10                    1562   19197     0.067729         72.438672
# 11                     941   18348     0.050167         78.787879
# 12                     865   16304     0.039683         42.567568
# 13                    1349   22302     0.008576         68.266979
# 14                    1539   24349     0.071111         64.562410
# 15                    1454   18317     0.019678         61.361142
# 16                    1343   10009     0.021739         84.975369
# 17                    1114   13923     0.078431         39.059081
# 18                    1345   22547     0.104956         38.324022
# 19                    1233   13470     0.025818         79.589041
# 20                    1182   17177     0.036090         86.363636
# 21                    1035   19641     0.021687         55.259654
# 22                     872   18423     0.021583         45.227766
# 23                    1384   19440     0.095355         59.275362
# 24                    1233   16735     0.027708         58.468336
# 25                     911   14073     0.090634         38.133641
# 26                     877   17260     0.086253         52.624113
# 27                    1018   24166     0.057637         49.571429
# 28                    1265   14673     0.096346         41.232877
# 29                    1393   22054     0.044855         51.285521
# 30                    1343   12579     0.024316         39.878788
# 31                     922   24586     0.026866         39.273154
# 32                    1335   15183     0.016207         79.510309
# 33                    1107   17491     0.049763         54.876463
# 34                    1071   12170     0.017799         91.964286
# 35                    1109   20021     0.033708         56.978233
# 36                     918   24577     0.017214         68.562232
# 37                    1008   21263     0.052392         52.827918
# 38                    1083   10722     0.018692         63.126844
# 39                     809   11832     0.086387         46.813725
# 40                    1115   15974     0.081800         70.461095
# 41                    1216   20168     0.017161         84.788360
# 42                    1140   22818     0.079487         59.360731
# 43                     839   24067     0.034404         49.209932
# 44                    1028   10387     0.050104         53.459821
# 45                    1456   18346     0.020362         47.021277
# 46                    1394   14349     0.038217         34.392114
# 47                     918   16311     0.052521         60.947503
# 48                    1351   21253     0.048338        101.689708
# 49                    1138   20209     0.065844         72.429210

# %% [markdown]
# # Q14. Find how many times each product_category appears in the dataset.

# %%
df['product_category'].value_counts()
# Out:
# product_category
# Automotive     18
# Electronics    16
# Furniture      16
# Name: count, dtype: int64

# %% [markdown]
# # Q15. Count the number of records for each shift.

# %% [markdown]
# # Q16. Find the most frequent supervisor using value_counts().

# %%
df['supervisor'].value_counts().head(1)
# Out:
# supervisor
# S3    15
# Name: count, dtype: int64

# %% [markdown]
# # Q17. Sort the dataset by profit in descending order.

# %%
df.sort_values(by='profit',ascending=False)
# Out:
#     production_id product_category  factory    shift supervisor  \
# 31            132       Automotive  Plant_A    Night         S1
# 36            137      Electronics  Plant_C    Night         S2
# 9             110       Automotive  Plant_B  Morning         S4
# 14            115       Automotive  Plant_B    Night         S2
# 27            128        Furniture  Plant_A  Morning         S4
# 43            144        Furniture  Plant_A  Morning         S4
# 2             103      Electronics  Plant_A    Night         S4
# 42            143        Furniture  Plant_C    Night         S2
# 8             109      Electronics  Plant_A  Morning         S3
# 18            119      Electronics  Plant_A    Night         S4
# 13            114        Furniture  Plant_C  Evening         S1
# 29            130       Automotive  Plant_A    Night         S3
# 37            138       Automotive  Plant_B    Night         S4
# 48            149       Automotive  Plant_C    Night         S2
# 5             106      Electronics  Plant_B  Morning         S2
# 49            150        Furniture  Plant_C  Morning         S3
# 41            142       Automotive  Plant_A  Morning         S2
# 35            136       Automotive  Plant_C  Morning         S3
# 21            122      Electronics  Plant_A  Morning         S1
# 23            124        Furniture  Plant_A  Evening         S4
# 10            111       Automotive  Plant_B    Night         S4
# 22            123      Electronics  Plant_B    Night         S4
# 11            112        Furniture  Plant_A  Morning         S1
# 45            146        Furniture  Plant_C    Night         S3
# 15            116       Automotive  Plant_A  Morning         S3
# 1             102       Automotive  Plant_A    Night         S2
# 33            134        Furniture  Plant_A  Morning         S4
# 26            127       Automotive  Plant_A  Morning         S1
# 20            121       Automotive  Plant_B  Morning         S2
# 24            125        Furniture  Plant_C  Morning         S1
# 47            148       Automotive  Plant_A  Evening         S1
# 12            113        Furniture  Plant_C  Evening         S3
# 40            141      Electronics  Plant_B  Morning         S2
# 32            133        Furniture  Plant_A    Night         S3
# 28            129        Furniture  Plant_C    Night         S4
# 46            147      Electronics  Plant_A    Night         S4
# 25            126      Electronics  Plant_A    Night         S4
# 7             108      Electronics  Plant_B  Evening         S3
# 17            118      Electronics  Plant_A    Night         S1
# 19            120       Automotive  Plant_C    Night         S2
# 6             107        Furniture  Plant_B  Morning         S3
# 30            131      Electronics  Plant_C  Morning         S2
# 0             101       Automotive  Plant_A    Night         S1
# 34            135        Furniture  Plant_A  Morning         S3
# 4             105        Furniture  Plant_A    Night         S3
# 39            140      Electronics  Plant_C  Morning         S1
# 3             104      Electronics  Plant_B  Morning         S3
# 38            139      Electronics  Plant_B  Morning         S3
# 44            145       Automotive  Plant_A  Evening         S3
# 16            117       Automotive  Plant_B  Evening         S1
#
#     units_produced  defective_units  production_time_hr  machine_downtime_hr  \
# 31             335                9                8.53                 0.51
# 36             639               11                9.32                 0.37
# 9              505               22                6.70                 1.39
# 14             450               32                6.97                 0.20
# 27             347               20                7.00                 0.83
# 43             436               15                8.86                 0.34
# 2              666               39                7.76                 0.78
# 42             390               31                6.57                 1.16
# 8              627               40                7.16                 0.62
# 18             343               36                8.95                 1.47
# 13             583                5                8.54                 0.35
# 29             379               17                7.39                 1.46
# 37             439               23                8.31                 1.13
# 48             662               32                6.51                 1.40
# 5              621               28                8.23                 1.12
# 49             486               32                6.71                 1.06
# 41             641               11                7.56                 0.93
# 35             445               15                7.81                 0.91
# 21             415                9                7.51                 0.96
# 23             409               39                6.90                 1.42
# 10             502               34                6.93                 0.38
# 22             417                9                9.22                 1.32
# 11             598               30                7.59                 1.50
# 45             442                9                9.40                 0.56
# 15             559               11                9.11                 0.59
# 1              602               32                6.60                 0.32
# 33             422               21                7.69                 1.07
# 26             371               32                7.05                 0.80
# 20             665               24                7.70                 1.07
# 24             397               11                6.79                 0.76
# 47             476               25                7.81                 1.48
# 12             378               15                8.88                 0.75
# 40             489               40                6.94                 0.37
# 32             617               10                7.76                 0.96
# 28             301               29                7.30                 1.22
# 46             314               12                9.13                 0.54
# 25             331               30                8.68                 1.24
# 7              659                9                8.33                 0.42
# 17             357               28                9.14                 1.28
# 19             581               15                7.30                 1.33
# 6              351               29                7.33                 1.03
# 30             329                8                8.25                 0.85
# 0              627               12                6.58                 0.56
# 34             618               11                6.72                 0.48
# 4              476               21                8.92                 1.15
# 39             382               33                8.16                 0.76
# 3              474               22                6.97                 1.44
# 38             428                8                6.78                 0.75
# 44             479               24                8.96                 1.33
# 16             690               15                8.12                 1.21
#
#     energy_consumption_kwh  profit  defect_rate  efficiency_score
# 31                     922   24586     0.026866         39.273154
# 36                     918   24577     0.017214         68.562232
# 9                     1380   24358     0.043564         75.373134
# 14                    1539   24349     0.071111         64.562410
# 27                    1018   24166     0.057637         49.571429
# 43                     839   24067     0.034404         49.209932
# 2                     1084   23261     0.058559         85.824742
# 42                    1140   22818     0.079487         59.360731
# 8                     1586   22713     0.063796         87.569832
# 18                    1345   22547     0.104956         38.324022
# 13                    1349   22302     0.008576         68.266979
# 29                    1393   22054     0.044855         51.285521
# 37                    1008   21263     0.052392         52.827918
# 48                    1351   21253     0.048338        101.689708
# 5                      846   20834     0.045089         75.455650
# 49                    1138   20209     0.065844         72.429210
# 41                    1216   20168     0.017161         84.788360
# 35                    1109   20021     0.033708         56.978233
# 21                    1035   19641     0.021687         55.259654
# 23                    1384   19440     0.095355         59.275362
# 10                    1562   19197     0.067729         72.438672
# 22                     872   18423     0.021583         45.227766
# 11                     941   18348     0.050167         78.787879
# 45                    1456   18346     0.020362         47.021277
# 15                    1454   18317     0.019678         61.361142
# 1                     1038   18279     0.053156         91.212121
# 33                    1107   17491     0.049763         54.876463
# 26                     877   17260     0.086253         52.624113
# 20                    1182   17177     0.036090         86.363636
# 24                    1233   16735     0.027708         58.468336
# 47                     918   16311     0.052521         60.947503
# 12                     865   16304     0.039683         42.567568
# 40                    1115   15974     0.081800         70.461095
# 32                    1335   15183     0.016207         79.510309
# 28                    1265   14673     0.096346         41.232877
# 46                    1394   14349     0.038217         34.392114
# 25                     911   14073     0.090634         38.133641
# 7                     1546   14010     0.013657         79.111645
# 17                    1114   13923     0.078431         39.059081
# 19                    1233   13470     0.025818         79.589041
# 6                     1173   12664     0.082621         47.885402
# 30                    1343   12579     0.024316         39.878788
# 0                     1028   12286     0.019139         95.288754
# 34                    1071   12170     0.017799         91.964286
# 4                     1349   12045     0.044118         53.363229
# 39                     809   11832     0.086387         46.813725
# 3                     1144   11674     0.046414         68.005739
# 38                    1083   10722     0.018692         63.126844
# 44                    1028   10387     0.050104         53.459821
# 16                    1343   10009     0.021739         84.975369

# %% [markdown]
# # Q18. Sort the dataset by:
# •	product_category ascending
# •	units_produced descending

# %%
df.sort_values(by=['product_category','units_produced'],ascending=[True,False])
# Out:
#     production_id product_category  factory    shift supervisor  \
# 16            117       Automotive  Plant_B  Evening         S1
# 20            121       Automotive  Plant_B  Morning         S2
# 48            149       Automotive  Plant_C    Night         S2
# 41            142       Automotive  Plant_A  Morning         S2
# 0             101       Automotive  Plant_A    Night         S1
# 1             102       Automotive  Plant_A    Night         S2
# 19            120       Automotive  Plant_C    Night         S2
# 15            116       Automotive  Plant_A  Morning         S3
# 9             110       Automotive  Plant_B  Morning         S4
# 10            111       Automotive  Plant_B    Night         S4
# 44            145       Automotive  Plant_A  Evening         S3
# 47            148       Automotive  Plant_A  Evening         S1
# 14            115       Automotive  Plant_B    Night         S2
# 35            136       Automotive  Plant_C  Morning         S3
# 37            138       Automotive  Plant_B    Night         S4
# 29            130       Automotive  Plant_A    Night         S3
# 26            127       Automotive  Plant_A  Morning         S1
# 31            132       Automotive  Plant_A    Night         S1
# 2             103      Electronics  Plant_A    Night         S4
# 7             108      Electronics  Plant_B  Evening         S3
# 36            137      Electronics  Plant_C    Night         S2
# 8             109      Electronics  Plant_A  Morning         S3
# 5             106      Electronics  Plant_B  Morning         S2
# 40            141      Electronics  Plant_B  Morning         S2
# 3             104      Electronics  Plant_B  Morning         S3
# 38            139      Electronics  Plant_B  Morning         S3
# 22            123      Electronics  Plant_B    Night         S4
# 21            122      Electronics  Plant_A  Morning         S1
# 39            140      Electronics  Plant_C  Morning         S1
# 17            118      Electronics  Plant_A    Night         S1
# 18            119      Electronics  Plant_A    Night         S4
# 25            126      Electronics  Plant_A    Night         S4
# 30            131      Electronics  Plant_C  Morning         S2
# 46            147      Electronics  Plant_A    Night         S4
# 34            135        Furniture  Plant_A  Morning         S3
# 32            133        Furniture  Plant_A    Night         S3
# 11            112        Furniture  Plant_A  Morning         S1
# 13            114        Furniture  Plant_C  Evening         S1
# 49            150        Furniture  Plant_C  Morning         S3
# 4             105        Furniture  Plant_A    Night         S3
# 45            146        Furniture  Plant_C    Night         S3
# 43            144        Furniture  Plant_A  Morning         S4
# 33            134        Furniture  Plant_A  Morning         S4
# 23            124        Furniture  Plant_A  Evening         S4
# 24            125        Furniture  Plant_C  Morning         S1
# 42            143        Furniture  Plant_C    Night         S2
# 12            113        Furniture  Plant_C  Evening         S3
# 6             107        Furniture  Plant_B  Morning         S3
# 27            128        Furniture  Plant_A  Morning         S4
# 28            129        Furniture  Plant_C    Night         S4
#
#     units_produced  defective_units  production_time_hr  machine_downtime_hr  \
# 16             690               15                8.12                 1.21
# 20             665               24                7.70                 1.07
# 48             662               32                6.51                 1.40
# 41             641               11                7.56                 0.93
# 0              627               12                6.58                 0.56
# 1              602               32                6.60                 0.32
# 19             581               15                7.30                 1.33
# 15             559               11                9.11                 0.59
# 9              505               22                6.70                 1.39
# 10             502               34                6.93                 0.38
# 44             479               24                8.96                 1.33
# 47             476               25                7.81                 1.48
# 14             450               32                6.97                 0.20
# 35             445               15                7.81                 0.91
# 37             439               23                8.31                 1.13
# 29             379               17                7.39                 1.46
# 26             371               32                7.05                 0.80
# 31             335                9                8.53                 0.51
# 2              666               39                7.76                 0.78
# 7              659                9                8.33                 0.42
# 36             639               11                9.32                 0.37
# 8              627               40                7.16                 0.62
# 5              621               28                8.23                 1.12
# 40             489               40                6.94                 0.37
# 3              474               22                6.97                 1.44
# 38             428                8                6.78                 0.75
# 22             417                9                9.22                 1.32
# 21             415                9                7.51                 0.96
# 39             382               33                8.16                 0.76
# 17             357               28                9.14                 1.28
# 18             343               36                8.95                 1.47
# 25             331               30                8.68                 1.24
# 30             329                8                8.25                 0.85
# 46             314               12                9.13                 0.54
# 34             618               11                6.72                 0.48
# 32             617               10                7.76                 0.96
# 11             598               30                7.59                 1.50
# 13             583                5                8.54                 0.35
# 49             486               32                6.71                 1.06
# 4              476               21                8.92                 1.15
# 45             442                9                9.40                 0.56
# 43             436               15                8.86                 0.34
# 33             422               21                7.69                 1.07
# 23             409               39                6.90                 1.42
# 24             397               11                6.79                 0.76
# 42             390               31                6.57                 1.16
# 12             378               15                8.88                 0.75
# 6              351               29                7.33                 1.03
# 27             347               20                7.00                 0.83
# 28             301               29                7.30                 1.22
#
#     energy_consumption_kwh  profit  defect_rate  efficiency_score
# 16                    1343   10009     0.021739         84.975369
# 20                    1182   17177     0.036090         86.363636
# 48                    1351   21253     0.048338        101.689708
# 41                    1216   20168     0.017161         84.788360
# 0                     1028   12286     0.019139         95.288754
# 1                     1038   18279     0.053156         91.212121
# 19                    1233   13470     0.025818         79.589041
# 15                    1454   18317     0.019678         61.361142
# 9                     1380   24358     0.043564         75.373134
# 10                    1562   19197     0.067729         72.438672
# 44                    1028   10387     0.050104         53.459821
# 47                     918   16311     0.052521         60.947503
# 14                    1539   24349     0.071111         64.562410
# 35                    1109   20021     0.033708         56.978233
# 37                    1008   21263     0.052392         52.827918
# 29                    1393   22054     0.044855         51.285521
# 26                     877   17260     0.086253         52.624113
# 31                     922   24586     0.026866         39.273154
# 2                     1084   23261     0.058559         85.824742
# 7                     1546   14010     0.013657         79.111645
# 36                     918   24577     0.017214         68.562232
# 8                     1586   22713     0.063796         87.569832
# 5                      846   20834     0.045089         75.455650
# 40                    1115   15974     0.081800         70.461095
# 3                     1144   11674     0.046414         68.005739
# 38                    1083   10722     0.018692         63.126844
# 22                     872   18423     0.021583         45.227766
# 21                    1035   19641     0.021687         55.259654
# 39                     809   11832     0.086387         46.813725
# 17                    1114   13923     0.078431         39.059081
# 18                    1345   22547     0.104956         38.324022
# 25                     911   14073     0.090634         38.133641
# 30                    1343   12579     0.024316         39.878788
# 46                    1394   14349     0.038217         34.392114
# 34                    1071   12170     0.017799         91.964286
# 32                    1335   15183     0.016207         79.510309
# 11                     941   18348     0.050167         78.787879
# 13                    1349   22302     0.008576         68.266979
# 49                    1138   20209     0.065844         72.429210
# 4                     1349   12045     0.044118         53.363229
# 45                    1456   18346     0.020362         47.021277
# 43                     839   24067     0.034404         49.209932
# 33                    1107   17491     0.049763         54.876463
# 23                    1384   19440     0.095355         59.275362
# 24                    1233   16735     0.027708         58.468336
# 42                    1140   22818     0.079487         59.360731
# 12                     865   16304     0.039683         42.567568
# 6                     1173   12664     0.082621         47.885402
# 27                    1018   24166     0.057637         49.571429
# 28                    1265   14673     0.096346         41.232877
